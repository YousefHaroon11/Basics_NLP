# %%
import spacy
nlp=spacy.load("en_core_web_sm")

# %%
from spacy import displacy

# %%
doc=nlp('Apple is going to build a U.K. factory for $6 million.')
displacy.render(doc,style='dep',jupyter=True,options={'distance':80})
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 2
#       1 doc=nlp('Apple is going to build a U.K. factory for $6 million.')
# ----> 2 displacy.render(doc,style='dep',jupyter=True,options={'distance':80})
#
# File ~\anaconda3\Lib\site-packages\spacy\displacy\__init__.py:69, in render(docs, style, page, minify, jupyter, options, manual)
#      65     html = RENDER_WRAPPER(html)
#      66 if jupyter or (jupyter is None and is_in_jupyter()):
#      67     # return HTML rendered by IPython display()
#      68     # See #4840 for details on span wrapper to disable mathjax
# ---> 69     from IPython.core.display import HTML, display
#      71     return display(HTML('<span class="tex2jax_ignore">{}</span>'.format(html)))
#      72 return html
#
# ImportError: cannot import name 'display' from 'IPython.core.display' (C:\Users\yousef_haroon\AppData\Roaming\Python\Python313\site-packages\IPython\core\display.py)

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'NLP4.ipynb', 'start2.ipynb', 'start3.ipynb', 'x.txt']

# %%
pip install --force-reinstall ipython
# Out:
# Collecting ipython
#   Downloading ipython-9.4.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting colorama (from ipython)
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting decorator (from ipython)
#   Using cached decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting ipython-pygments-lexers (from ipython)
#   Using cached ipython_pygments_lexers-1.1.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting jedi>=0.16 (from ipython)
#   Using cached jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting matplotlib-inline (from ipython)
#   Using cached matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# Collecting prompt_toolkit<3.1.0,>=3.0.41 (from ipython)
#   Using cached prompt_toolkit-3.0.51-py3-none-any.whl.metadata (6.4 kB)
# Collecting pygments>=2.4.0 (from ipython)
#   Downloading pygments-2.19.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting stack_data (from ipython)
#   Using cached stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting traitlets>=5.13.0 (from ipython)
#   Using cached traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting wcwidth (from prompt_toolkit<3.1.0,>=3.0.41->ipython)
#   Using cached wcwidth-0.2.13-py2.py3-none-any.whl.metadata (14 kB)
# Collecting parso<0.9.0,>=0.8.4 (from jedi>=0.16->ipython)
#   Using cached parso-0.8.4-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting executing>=1.2.0 (from stack_data->ipython)
#   Using cached executing-2.2.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data->ipython)
#   Using cached asttokens-3.0.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting pure-eval (from stack_data->ipython)
#   Using cached pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Downloading ipython-9.4.0-py3-none-any.whl (611 kB)
#    ---------------------------------------- 0.0/611.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/611.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/611.0 kB ? eta -:--:--
#    ----------------- ---------------------- 262.1/611.0 kB ? eta -:--:--
#    ----------------- ---------------------- 262.1/611.0 kB ? eta -:--:--
#    ----------------- ---------------------- 262.1/611.0 kB ? eta -:--:--
#    -------------------------------- ----- 524.3/611.0 kB 372.3 kB/s eta 0:00:01
#    -------------------------------- ----- 524.3/611.0 kB 372.3 kB/s eta 0:00:01
#    -------------------------------- ----- 524.3/611.0 kB 372.3 kB/s eta 0:00:01
#    -------------------------------------- 611.0/611.0 kB 260.5 kB/s eta 0:00:00
# Using cached prompt_toolkit-3.0.51-py3-none-any.whl (387 kB)
# Using cached jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
# Using cached parso-0.8.4-py2.py3-none-any.whl (103 kB)
# Downloading pygments-2.19.2-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ------------------------- -------------- 0.8/1.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.0/1.2 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 1.7 MB/s eta 0:00:00
# Using cached traitlets-5.14.3-py3-none-any.whl (85 kB)
# Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Using cached decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Using cached ipython_pygments_lexers-1.1.1-py3-none-any.whl (8.1 kB)
# Using cached matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Using cached stack_data-0.6.3-py3-none-any.whl (24 kB)
# Using cached asttokens-3.0.0-py3-none-any.whl (26 kB)
# Using cached executing-2.2.0-py2.py3-none-any.whl (26 kB)
# Using cached pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Using cached wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Installing collected packages: wcwidth, pure-eval, traitlets, pygments, prompt_toolkit, parso, executing, decorator, colorama, asttokens, stack_data, matplotlib-inline, jedi, ipython-pygments-lexers, ipython
#
#   Attempting uninstall: wcwidth
#
#     Found existing installation: wcwidth 0.2.13
#
#     Uninstalling wcwidth-0.2.13:
#
#       Successfully uninstalled wcwidth-0.2.13
#
#    ----------------------------------------  0/15 [wcwidth]
#   Attempting uninstall: pure-eval
#    ----------------------------------------  0/15 [wcwidth]
#     Found existing installation: pure_eval 0.2.3
#    ----------------------------------------  0/15 [wcwidth]
#     Uninstalling pure_eval-0.2.3:
#    ----------------------------------------  0/15 [wcwidth]
#       Successfully uninstalled pure_eval-0.2.3
#    ----------------------------------------  0/15 [wcwidth]
#   Attempting uninstall: traitlets
#    ----------------------------------------  0/15 [wcwidth]
#     Found existing installation: traitlets 5.14.3
#    ----------------------------------------  0/15 [wcwidth]
#    ----- ----------------------------------  2/15 [traitlets]
#     Uninstalling traitlets-5.14.3:
#    ----- ----------------------------------  2/15 [traitlets]
#       Successfully uninstalled traitlets-5.14.3
#    ----- ----------------------------------  2/15 [traitlets]
#    ----- ----------------------------------  2/15 [traitlets]
#   Attempting uninstall: pygments
#    ----- ----------------------------------  2/15 [traitlets]
#    -------- -------------------------------  3/15 [pygments]
#     Found existing installation: Pygments 2.19.1
#    -------- -------------------------------  3/15 [pygments]
#    -------- -------------------------------  3/15 [pygments]
#     Uninstalling Pygments-2.19.1:
#    -------- -------------------------------  3/15 [pygments]
#       Successfully uninstalled Pygments-2.19.1
#    -------- -------------------------------  3/15 [pygments]
#    -------- -------------------------------  3/15 [pygments]
#    -------- -------------------------------  3/15 [pygments]
#    -------- -------------------------------  3/15 [pygments]
#    -------- -------------------------------  3/15 [pygments]
#    -------- -------------------------------  3/15 [pygments]
#    -------- -------------------------------  3/15 [pygments]
#    -------- -------------------------------  3/15 [pygments]
#    -------- -------------------------------  3/15 [pygments]
#    -------- -------------------------------  3/15 [pygments]
#    -------- -------------------------------  3/15 [pygments]
#    -------- -------------------------------  3/15 [pygments]
#    -------- -------------------------------  3/15 [pygments]
#    -------- -------------------------------  3/15 [pygments]
#    -------- -------------------------------  3/15 [pygments]
#    -------- -------------------------------  3/15 [pygments]
#    -------- -------------------------------  3/15 [pygments]
#    -------- -------------------------------  3/15 [pygments]
#    -------- -------------------------------  3/15 [pygments]
#   Attempting uninstall: prompt_toolkit
#    -------- -------------------------------  3/15 [pygments]
#     Found existing installation: prompt_toolkit 3.0.51
#    -------- -------------------------------  3/15 [pygments]
#    ---------- -----------------------------  4/15 [prompt_toolkit]
#     Uninstalling prompt_toolkit-3.0.51:
#    ---------- -----------------------------  4/15 [prompt_toolkit]
#       Successfully uninstalled prompt_toolkit-3.0.51
#    ---------- -----------------------------  4/15 [prompt_toolkit]
#    ---------- -----------------------------  4/15 [prompt_toolkit]
#    ---------- -----------------------------  4/15 [prompt_toolkit]
#    ---------- -----------------------------  4/15 [prompt_toolkit]
#    ---------- -----------------------------  4/15 [prompt_toolkit]
#    ---------- -----------------------------  4/15 [prompt_toolkit]
#    ---------- -----------------------------  4/15 [prompt_toolkit]
#    ---------- -----------------------------  4/15 [prompt_toolkit]
#    ---------- -----------------------------  4/15 [prompt_toolkit]
#    ---------- -----------------------------  4/15 [prompt_toolkit]
#   Attempting uninstall: parso
#    ---------- -----------------------------  4/15 [prompt_toolkit]
#     Found existing installation: parso 0.8.4
#    ---------- -----------------------------  4/15 [prompt_toolkit]
#     Uninstalling parso-0.8.4:
#    ---------- -----------------------------  4/15 [prompt_toolkit]
#       Successfully uninstalled parso-0.8.4
#    ---------- -----------------------------  4/15 [prompt_toolkit]
#    ------------- --------------------------  5/15 [parso]
#    ------------- --------------------------  5/15 [parso]
#   Attempting uninstall: executing
#    ------------- --------------------------  5/15 [parso]
#     Found existing installation: executing 2.2.0
#    ------------- --------------------------  5/15 [parso]
#    ---------------- -----------------------  6/15 [executing]
#     Uninstalling executing-2.2.0:
#    ---------------- -----------------------  6/15 [executing]
#       Successfully uninstalled executing-2.2.0
#    ---------------- -----------------------  6/15 [executing]
#   Attempting uninstall: decorator
#    ---------------- -----------------------  6/15 [executing]
#     Found existing installation: decorator 5.2.1
#    ---------------- -----------------------  6/15 [executing]
#     Uninstalling decorator-5.2.1:
#    ---------------- -----------------------  6/15 [executing]
#    ------------------ ---------------------  7/15 [decorator]
#       Successfully uninstalled decorator-5.2.1
#    ------------------ ---------------------  7/15 [decorator]
#   Attempting uninstall: colorama
#    ------------------ ---------------------  7/15 [decorator]
#    --------------------- ------------------  8/15 [colorama]
#     Found existing installation: colorama 0.4.6
#    --------------------- ------------------  8/15 [colorama]
#     Uninstalling colorama-0.4.6:
#    --------------------- ------------------  8/15 [colorama]
#       Successfully uninstalled colorama-0.4.6
#    --------------------- ------------------  8/15 [colorama]
#   Attempting uninstall: asttokens
#    --------------------- ------------------  8/15 [colorama]
#     Found existing installation: asttokens 3.0.0
#    --------------------- ------------------  8/15 [colorama]
#    ------------------------ ---------------  9/15 [asttokens]
#     Uninstalling asttokens-3.0.0:
#    ------------------------ ---------------  9/15 [asttokens]
#       Successfully uninstalled asttokens-3.0.0
#    ------------------------ ---------------  9/15 [asttokens]
#   Attempting uninstall: stack_data
#    ------------------------ ---------------  9/15 [asttokens]
#     Found existing installation: stack-data 0.6.3
#    ------------------------ ---------------  9/15 [asttokens]
#     Uninstalling stack-data-0.6.3:
#    ------------------------ ---------------  9/15 [asttokens]
#       Successfully uninstalled stack-data-0.6.3
#    ------------------------ ---------------  9/15 [asttokens]
#    -------------------------- ------------- 10/15 [stack_data]
#   Attempting uninstall: matplotlib-inline
#    -------------------------- ------------- 10/15 [stack_data]
#     Found existing installation: matplotlib-inline 0.1.7
#    -------------------------- ------------- 10/15 [stack_data]
#     Uninstalling matplotlib-inline-0.1.7:
#    -------------------------- ------------- 10/15 [stack_data]
#       Successfully uninstalled matplotlib-inline-0.1.7
#    -------------------------- ------------- 10/15 [stack_data]
#    ----------------------------- ---------- 11/15 [matplotlib-inline]
#   Attempting uninstall: jedi
#    ----------------------------- ---------- 11/15 [matplotlib-inline]
#     Found existing installation: jedi 0.19.2
#    ----------------------------- ---------- 11/15 [matplotlib-inline]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#     Uninstalling jedi-0.19.2:
#    -------------------------------- ------- 12/15 [jedi]
#       Successfully uninstalled jedi-0.19.2
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#    -------------------------------- ------- 12/15 [jedi]
#   Attempting uninstall: ipython-pygments-lexers
#    -------------------------------- ------- 12/15 [jedi]
#     Found existing installation: ipython_pygments_lexers 1.1.1
#    -------------------------------- ------- 12/15 [jedi]
#     Uninstalling ipython_pygments_lexers-1.1.1:
#    -------------------------------- ------- 12/15 [jedi]
#    ---------------------------------- ----- 13/15 [ipython-pygments-lexers]
#       Successfully uninstalled ipython_pygments_lexers-1.1.1
#    ---------------------------------- ----- 13/15 [ipython-pygments-lexers]
#   Attempting uninstall: ipython
#    ---------------------------------- ----- 13/15 [ipython-pygments-lexers]
#     Found existing installation: ipython 9.1.0
#    ---------------------------------- ----- 13/15 [ipython-pygments-lexers]
#    ------------------------------------- -- 14/15 [ipython]
#     Uninstalling ipython-9.1.0:
#    ------------------------------------- -- 14/15 [ipython]
#    ------------------------------------- -- 14/15 [ipython]
#    ------------------------------------- -- 14/15 [ipython]
#    ------------------------------------- -- 14/15 [ipython]
#    ------------------------------------- -- 14/15 [ipython]
#    ------------------------------------- -- 14/15 [ipython]
#       Successfully uninstalled ipython-9.1.0
#    ------------------------------------- -- 14/15 [ipython]
#    ------------------------------------- -- 14/15 [ipython]
#    ------------------------------------- -- 14/15 [ipython]
#    ------------------------------------- -- 14/15 [ipython]
#    ------------------------------------- -- 14/15 [ipython]
#    ------------------------------------- -- 14/15 [ipython]
#    ------------------------------------- -- 14/15 [ipython]
#    ------------------------------------- -- 14/15 [ipython]
#    ------------------------------------- -- 14/15 [ipython]
#    ------------------------------------- -- 14/15 [ipython]
#    ------------------------------------- -- 14/15 [ipython]
#    ------------------------------------- -- 14/15 [ipython]
#    ---------------------------------------- 15/15 [ipython]
#
# Successfully installed asttokens-3.0.0 colorama-0.4.6 decorator-5.1.1 executing-0.8.3 ipython-8.30.0 ipython-pygments-lexers-1.1.1 jedi-0.19.2 matplotlib-inline-0.1.6 parso-0.8.4 prompt_toolkit-3.0.43 pure-eval-0.2.2 pygments-2.19.1 stack_data-0.2.0 traitlets-5.14.3 wcwidth-0.2.13
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 6.0.7 requires ipython!=8.17.1,<9.0.0,>=8.13.0; python_version > "3.8", but you have ipython 9.4.0 which is incompatible.
# spyder-kernels 3.0.5 requires ipython!=8.17.1,<9,>=8.13.0; python_version > "3.8", but you have ipython 9.4.0 which is incompatible.
